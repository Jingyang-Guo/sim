# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

conn = sqlite3.connect("conversations.db", check_same_thread=False)
checkpointer = SqliteSaver(conn)

cursor = conn.cursor()
cursor.execute("SELECT DISTINCT thread_id FROM checkpoints")
threads = cursor.fetchall()
# print(f"Threads in DB: {threads}")
print(len(threads))
# Out:
# 2058

# %%
config = {"configurable": {"thread_id": "2058"}}
data = checkpointer.get(config)

data["channel_values"]["messages"][-1].content
# Out:
# 'Now I have enough information to answer the survey questions. Based on the persona\'s profile:\n- Asian male, 30-49, married with household of 4\n- Postgraduate education, $100k+ income\n- Democrat, liberal political views\n- Protestant, attends religious services weekly\n- High conscientiousness, extraversion, agreeableness\n- Strong environmental values\n- High empathy and collectivist tendencies\n- Good numeracy and cognitive reflection skills\n- Somewhat risk-averse\n\nLet me answer the questions systematically:\n\n```json\n{\n    "Q1": {\n        "Question Type": "Matrix",\n        "Answers": {\n            "SelectedByPosition": [4, 5, 5, 5, 5, 5, 5, 5, 2, 3],\n            "SelectedText": ["Somewhat support", "Strongly support", "Strongly support", "Strongly support", "Strongly support", "Strongly support", "Strongly support", "Strongly support", "Somewhat oppose", "Neither oppose nor support"]\n        }\n    },\n    "Q2": {\n        "Question Type": "Slider",\n        "Answers": {\n            "Values": ["30"]\n        }\n    },\n    "Q3": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 2,\n            "SelectedText": "I favor program A"\n        }\n    },\n    "Q4": {\n        "Question Type": "Matrix",\n        "Answers": {\n            "SelectedByPosition": [3, 4, 4],\n            "SelectedText": ["Somewhat probable", "Moderately probable", "Moderately probable"]\n        }\n    },\n    "Q5": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 6,\n            "SelectedText": "Correct, all things considered"\n        }\n    },\n    "Q6": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 1,\n            "SelectedText": "more"\n        }\n    },\n    "Q7": {\n        "Question Type": "Text Entry",\n        "Answers": {\n            "Text": "54"\n        }\n    },\n    "Q8": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 2,\n            "SelectedText": "less"\n        }\n    },\n    "Q9": {\n        "Question Type": "Text Entry",\n        "Answers": {\n            "Text": "380"\n        }\n    },\n    "Q10": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 2,\n            "SelectedText": "Disagree a little"\n        }\n    },\n    "Q11": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 5,\n            "SelectedText": "Agree strongly"\n        }\n    },\n    "Q12": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 6,\n            "SelectedText": "very likely"\n        }\n    },\n    "Q13": {\n        "Question Type": "Text Entry",\n        "Answers": {\n            "Text": "15"\n        }\n    },\n    "Q14": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 1,\n            "SelectedText": "Yes"\n        }\n    },\n    "Q15": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 3,\n            "SelectedText": "$1,000"\n        }\n    },\n    "Q16": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 1,\n            "SelectedText": "One million dollars for sure"\n        }\n    },\n    "Q17": {\n        "Question Type": "Single Choice",\n        "Answers": {\n            "SelectedByPosition": 4,\n            "SelectedText": "probably yes"\n        }\n    },\n    "Q18": {\n        "Question Type": "Matrix",\n        "Answers": {\n            "SelectedByPosition": [1, 1, 1, 1, 1, 1],\n            "SelectedText": ["red", "red", "red", "red", "red", "red"]\n        }\n    },\n    "Q19": {\n        "Question Type": "Matrix",\n        "Answers": {\n            "SelectedByPosition": [7, 3, 5, 4],\n            "SelectedT ...

# %%
conn.close()
