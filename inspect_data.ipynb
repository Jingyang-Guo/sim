# %% [markdown]
# [Twin-2K-500](https://huggingface.co/datasets/LLM-Digital-Twin/Twin-2K-500)
#
# [Document](https://digital-twin-simulation-version2.readthedocs.io/en/latest/index.html)

# %% [markdown]
# 任务名称映射
#
# Demographics
#
# - Element 0: `Demographics`, `11-24`
#
# Personality traits
#
# - Element 1: `Big 5 personality test`, `25`
#
# - Element 1: `Need for cognition scale`, `26`
#
# - Element 1: `Agentic vs. Communal Values scale`, `29`
#
# - Element 1: `Consumer Minimalism scale`, `35`
#
# - Element 1: `Empathy scale`, `232`
#
# - Element 1: `Green values scale`, `235`
#
# - Element 5: `Social Desirability scale`, `27`
#
# - Element 5: `Conscientiousness scale`, `30`
#
# - Element 5: `Anxiety scale`, `125`
#
# - Element 5: `Individualism vs. Collectivism scale`, `233`
#
# - Element 5: `Selves questionnaire`, `268-270`
#
# - Element 10: `Regulatory Focus scale`, `28`
#
# - Element 10: `Tightwads vs. Spendthrift scale`, `31-34`
#
# - Element 10: `Depression scale`, `*127*, 126, 128-134, 136-139, *240*, 140-148`
#
# - Element 10: `Need for uniqueness scale`, `234`
#
# - Element 10: `Self-monitoring scale`, `236`
#
# - Element 10: `Self-concept clarity scale`, `237`
#
# - Element 10: `Need for closure scale`, `238`
#
# - Element 10: `Maximization scale`, `239`
#
# Cognitive abilities
#
# - Element 2: `Cognitive Reflection Test`, `52-55`
#
# - Element 2: `Fluid intelligence test`, `56-61`
#
# - Element 2: `Crystallized intelligence test`, `62-79, 81, 82, 83, 80`
#
# - Element 2: `Syllogisms test`, `278, 268-270, 279, 271-277`
#
# - Element 2: `Overconfidence`, `123`
#
# - Element 2: `Overplacement`, `124`
#
# - Element 6: `Financial literacy test`, `36-43`
#
# - Element 6: `Numeracy test`, `44-51`
#
# - Element 6: `Deductive certainty of Modus Ponens test`, `217-220`
#
# - Element 7: `Forward Flow (free associations)`, `10`
#
# - Element 11: `Wason Selection Task`, `221`
#
# Economic preferences
#
# - Element 4: `Ultimatum game (sender)`, `224`
#
# - Element 4: `Ultimatum game (receiver)`, `225-230`
#
# - Element 4: `Mental accounting`, `149-152`
#
# - Element 9: `Discount`, `*243*, 84, 244, 245`
#
# - Element 9: `Present bias`, `246, 247, 248`
#
# - Element 9: `Risk Aversion`, `*249*, 250, 251, 252`
#
# - Element 9: `Loss Aversion`, `276, 277, 278, 279`
#
# - Element 9: `Trust game (sender)`, `117`
#
# - Element 9: `Trust game (receiver)`, `118, 119, 120, 121, 122`
#
# - Element 9: `Trust game (sender) thought listing`, `271`
#
# - Element 9: `Trust game (receiver) thought listing`, `272`
#
# - Element 12: `Dictator game`, `231`
#
# - Element 12: `Dictator game thought listing`, `275`
#
# Heuristics and biases (between subject)
#
# - Element 14: `Base rate problem`
#
# - Element 17: `Outcome bias`
#
# - Element 23: `Sunk cost fallacy`
#
# - Element 26: `Allais problem`
#
# - Element 15: `Framing problem`
#
# - Element 16: `Conjunction problem (Linda)`
#
# - Element 18+19: `Anchoring and adjustment`
#
# - Element 24: `Absolute vs. relative savings`
#
# - Element 27: `Myside bias`
#
# - Element 20+21+22: `Less is More`
#
# - Element 25: `WTA/WTP-Thaler problem`
#
#
# Heuristics and biases (within subject)
#
# - Element 13+29: `False consensus`
#
# - Element 29: `Nonseparability of risk and benefits judgments`
#
# - Element 29: `Omission bias`
#
# - Element 28: `Probability matching vs. maximizing`
#
# - Element 29: `Dominator neglect`
#
#
# Product preferences
# - Element 30: `Pricing study`

# %% [markdown]
# data
#
# - mega_persona_json
#   - answer_blocks
#     - wave4_Q_wave1_3_A: `hold-out问题和回答`(ground truth)
#     - wave4_Q_wave4_A: `hold-out问题和回答`（retest）
#   - mega_persona: `non-hold-out问题和回答`
#
# - mega_persona_summary_text
#
# - wave_csv

# %% [markdown]
# <br>
